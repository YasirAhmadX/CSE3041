# %% [markdown]
# # Practice Questions
# ## Yasir Ahmad 22MIA1064

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # <u> Q1– Sales Dataset</u>
# ### 1 Read sales2.csv file into a dataframe

# %%
df = pd.read_csv("/home/ex5/Downloads/sales2.csv")
df
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  05-10-2012         3001         5002
# 1    70009     270.65  09-10-2012         3001         5005
# 2    70002      65.26  05-10-2012         3005         5001
# 3    70004     110.50  08-17-2012         3001         5003
# 4    70007     948.50  10-09-2012         3005         5002
# 5    70005    2400.60  07-27-2012         3001         5001
# 6    70008    5760.00  10-09-2012         3005         5001
# 7    70010    1983.43  10-10-2012         3001         5006
# 8    70003    2480.40  10-10-2012         3005         5003
# 9    70012     250.45  06-17-2012         3001         5002
# 10   70011      75.29  07-08-2012         3005         5007
# 11   70013    3045.60  04-25-2012         3005         5001

# %% [markdown]
# ### 2 Display the first few records

# %%
df.head()
# Out:
#    ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001     150.50  05-10-2012         3001         5002
# 1   70009     270.65  09-10-2012         3001         5005
# 2   70002      65.26  05-10-2012         3005         5001
# 3   70004     110.50  08-17-2012         3001         5003
# 4   70007     948.50  10-09-2012         3005         5002

# %% [markdown]
# ### 3 Describe the dataset.

# %%
df.describe()
# Out:
#              ord_no    purch_amt  customer_id  salesman_id
# count     12.000000    12.000000    12.000000    12.000000
# mean   70007.083333  1461.765000  3003.000000  5002.833333
# std        4.055486  1751.411698     2.088932     2.081666
# min    70001.000000    65.260000  3001.000000  5001.000000
# 25%    70003.750000   140.500000  3001.000000  5001.000000
# 50%    70007.500000   609.575000  3003.000000  5002.000000
# 75%    70010.250000  2420.550000  3005.000000  5003.500000
# max    70013.000000  5760.000000  3005.000000  5007.000000

# %% [markdown]
# ### 4 Check for NA values

# %%
df.isnull().sum()
# Out:
# ord_no         0
# purch_amt      0
# ord_date       0
# customer_id    0
# salesman_id    0
# dtype: int64

# %% [markdown]
# ### 5 Plot a bar graph for ord_date Vs Purchase amount

# %%
df.plot(x='ord_date',y='purch_amt',kind='bar')
plt.show()

# %% [markdown]
# ### 6 Fetch the details of customer id 3001

# %%
df[df['customer_id']==3001]
# Out:
#    ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001     150.50  05-10-2012         3001         5002
# 1   70009     270.65  09-10-2012         3001         5005
# 3   70004     110.50  08-17-2012         3001         5003
# 5   70005    2400.60  07-27-2012         3001         5001
# 7   70010    1983.43  10-10-2012         3001         5006
# 9   70012     250.45  06-17-2012         3001         5002

# %% [markdown]
# ### 7 Update the purchase amount of order Id 70012 as 500

# %%
df.loc[df['ord_no']==70012]
# Out:
#    ord_no  purch_amt    ord_date  customer_id  salesman_id
# 9   70012     250.45  06-17-2012         3001         5002

# %% [markdown]
# ### 8 Retrieve the order no and customer id of the maximum purchase amount

# %%
df.loc[(df['purch_amt']==df['purch_amt'].max()),['ord_no','customer_id']]
# Out:
#    ord_no  customer_id
# 6   70008         3005

# %% [markdown]
# ### 9 Retrieve the order no, customer id and purchase amount whose value is greater than 1000

# %%
df[df['purch_amt']>1000][['ord_no','customer_id','purch_amt']]
# Out:
#     ord_no  customer_id  purch_amt
# 5    70005         3001    2400.60
# 6    70008         3005    5760.00
# 7    70010         3001    1983.43
# 8    70003         3005    2480.40
# 11   70013         3005    3045.60

# %% [markdown]
# ### 10 Fetch the order details that are placed during the month of October

# %%
df['ord_date'] = pd.to_datetime(df['ord_date'])
df[df['ord_date'].dt.month==10]
# Out:
#    ord_no  purch_amt   ord_date  customer_id  salesman_id
# 4   70007     948.50 2012-10-09         3005         5002
# 6   70008    5760.00 2012-10-09         3005         5001
# 7   70010    1983.43 2012-10-10         3001         5006
# 8   70003    2480.40 2012-10-10         3005         5003

# %% [markdown]
# ### 11 Split the dataset into groups on customer_id to summarize purch_amt with respect to each salesman id

# %%
p_df = df.groupby('salesman_id')[['customer_id','purch_amt']]
p_df.describe()
# Out:
#             customer_id                                                 \
#                   count         mean       std     min     25%     50%
# salesman_id
# 5001                4.0  3004.000000  2.000000  3001.0  3004.0  3005.0
# 5002                3.0  3002.333333  2.309401  3001.0  3001.0  3001.0
# 5003                2.0  3003.000000  2.828427  3001.0  3002.0  3003.0
# 5005                1.0  3001.000000       NaN  3001.0  3001.0  3001.0
# 5006                1.0  3001.000000       NaN  3001.0  3001.0  3001.0
# 5007                1.0  3005.000000       NaN  3005.0  3005.0  3005.0
#
#                             purch_amt                                     \
#                 75%     max     count         mean          std      min
# salesman_id
# 5001         3005.0  3005.0       4.0  2817.865000  2342.289902    65.26
# 5002         3003.0  3005.0       3.0   449.816667   434.754299   150.50
# 5003         3004.0  3005.0       2.0  1295.450000  1675.772361   110.50
# 5005         3001.0  3001.0       1.0   270.650000          NaN   270.65
# 5006         3001.0  3001.0       1.0  1983.430000          NaN  1983.43
# 5007         3005.0  3005.0       1.0    75.290000          NaN    75.29
#
#
#                   25%      50%       75%      max
# salesman_id
# 5001         1816.765  2723.10  3724.200  5760.00
# 5002          200.475   250.45   599.475   948.50
# 5003          702.975  1295.45  1887.925  2480.40
# 5005          270.650   270.65   270.650   270.65
# 5006         1983.430  1983.43  1983.430  1983.43
# 5007           75.290    75.29    75.290    75.29

# %% [markdown]
# ### 12 Calculate percentage of purch_amt in each group and rename purch_amt to purchaseAmount.

# %%
totalPurch = df['purch_amt'].sum()

# %%
p_df.sum()
# Out:
#              customer_id  purch_amt
# salesman_id
# 5001               12016   11271.46
# 5002                9007    1349.45
# 5003                6006    2590.90
# 5005                3001     270.65
# 5006                3001    1983.43
# 5007                3005      75.29

# %%
PurchPct = sum(p_df['purch_amt'])*100 /totalPurch
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [152], line 1
# ----> 1 PurchPct = sum(p_df[['purch_amt']])*100 /totalPurch
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/generic.py:1411, in DataFrameGroupBy.__getitem__(self, key)
#    1402 if isinstance(key, tuple) and len(key) > 1:
#    1403     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1404     # valid syntax, so don't raise warning
#    1405     warnings.warn(
#    1406         "Indexing with multiple keys (implicitly converted to a tuple "
#    1407         "of keys) will be deprecated, use a list instead.",
#    1408         FutureWarning,
#    1409         stacklevel=find_stack_level(inspect.currentframe()),
#    1410     )
# -> 1411 return super().__getitem__(key)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/base.py:233, in SelectionMixin.__getitem__(self, key)
#     231 def __getitem__(self, key):
#     232     if self._selection is not None:
# --> 233         raise IndexError(f"Column(s) {self._selection} already selected")
#     235     if isinstance(key, (list, tuple, ABCSeries, ABCIndex, np.ndarray)):
#     236         if len(self.obj.columns.intersection(key)) != len(set(key)):
#
# IndexError: Column(s) ['customer_id', 'purch_amt'] already selected

# %%
df['PurchPct'] = PurchPct
df
# Out:
#     ord_no  purch_amt   ord_date  customer_id  salesman_id  PurchPct
# 0    70001     150.50 2012-05-10         3001         5002       NaN
# 1    70009     270.65 2012-09-10         3001         5005       NaN
# 2    70002      65.26 2012-05-10         3005         5001       NaN
# 3    70004     110.50 2012-08-17         3001         5003       NaN
# 4    70007     948.50 2012-10-09         3005         5002       NaN
# 5    70005    2400.60 2012-07-27         3001         5001       NaN
# 6    70008    5760.00 2012-10-09         3005         5001       NaN
# 7    70010    1983.43 2012-10-10         3001         5006       NaN
# 8    70003    2480.40 2012-10-10         3005         5003       NaN
# 9    70012     250.45 2012-06-17         3001         5002       NaN
# 10   70011      75.29 2012-07-08         3005         5007       NaN
# 11   70013    3045.60 2012-04-25         3005         5001       NaN

# %%
df.rename(columns={'purch_amt':'purchaseAmount'},inplace = True)
df
# Out:
#     ord_no  purchaseAmount    ord_date  customer_id  salesman_id
# 0    70001          150.50  05-10-2012         3001         5002
# 1    70009          270.65  09-10-2012         3001         5005
# 2    70002           65.26  05-10-2012         3005         5001
# 3    70004          110.50  08-17-2012         3001         5003
# 4    70007          948.50  10-09-2012         3005         5002
# 5    70005         2400.60  07-27-2012         3001         5001
# 6    70008         5760.00  10-09-2012         3005         5001
# 7    70010         1983.43  10-10-2012         3001         5006
# 8    70003         2480.40  10-10-2012         3005         5003
# 9    70012          250.45  06-17-2012         3001         5002
# 10   70011           75.29  07-08-2012         3005         5007
# 11   70013         3045.60  04-25-2012         3005         5001

# %% [markdown]
# # <u>Q2- Iris Datase</u>
# ### 1 Load the iris.csv file into a dataframe.

# %%
df = pd.read_csv("/home/ex5/Downloads/iris.csv")

# %% [markdown]
# ### 2 Displaying the shape of the dataset.

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# ### 3 Display a sample of 10 records.

# %%
df.sample(10)
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 9     10           4.9          3.1           1.5          0.1
# 94    95           5.6          2.7           4.2          1.3
# 101  102           5.8          2.7           5.1          1.9
# 147  148           6.5          3.0           5.2          2.0
# 54    55           6.5          2.8           4.6          1.5
# 109  110           7.2          3.6           6.1          2.5
# 10    11           5.4          3.7           1.5          0.2
# 51    52           6.4          3.2           4.5          1.5
# 56    57           6.3          3.3           4.7          1.6
# 64    65           5.6          2.9           3.6          1.3
#
#              species
# 9        Iris-setosa
# 94   Iris-versicolor
# 101   Iris-virginica
# 147   Iris-virginica
# 54   Iris-versicolor
# 109   Iris-virginica
# 10       Iris-setosa
# 51   Iris-versicolor
# 56   Iris-versicolor
# 64   Iris-versicolor

# %% [markdown]
# ### 4 Display the records from 10th row to 20th row.

# %%
df.iloc[10:21]
# Out:
#     Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width      species
# 10  11           5.4          3.7           1.5          0.2  Iris-setosa
# 11  12           4.8          3.4           1.6          0.2  Iris-setosa
# 12  13           4.8          3.0           1.4          0.1  Iris-setosa
# 13  14           4.3          3.0           1.1          0.1  Iris-setosa
# 14  15           5.8          4.0           1.2          0.2  Iris-setosa
# 15  16           5.7          4.4           1.5          0.4  Iris-setosa
# 16  17           5.1          3.5           1.4          0.3  Iris-setosa
# 17  18           5.4          3.9           1.3          0.4  Iris-setosa
# 18  19           5.7          3.8           1.7          0.3  Iris-setosa
# 19  20           5.1          3.8           1.5          0.3  Iris-setosa
# 20  21           5.4          3.4           1.7          0.2  Iris-setosa

# %%
### 5 Drop the duplicate records.

# %%
### 6 Count the number of unique species

# %% [markdown]
# ### 7 Sort the data based on the sepal length

# %%
df.sort_values('Sepal.Length')
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width         species
# 13    14           4.3          3.0           1.1          0.1     Iris-setosa
# 42    43           4.4          3.2           1.3          0.2     Iris-setosa
# 38    39           4.4          3.0           1.3          0.2     Iris-setosa
# 8      9           4.4          2.9           1.4          0.2     Iris-setosa
# 41    42           4.5          2.3           1.3          0.3     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 122  123           7.7          2.8           6.7          2.0  Iris-virginica
# 118  119           7.7          2.6           6.9          2.3  Iris-virginica
# 117  118           7.7          3.8           6.7          2.2  Iris-virginica
# 135  136           7.7          3.0           6.1          2.3  Iris-virginica
# 131  132           7.9          3.8           6.4          2.0  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### 8 Calculate sum, mean and mode of petal length.

# %%
df['Petal.Length'].agg(['sum','mean'])
# Out:
# sum     563.800000
# mean      3.758667
# Name: Petal.Length, dtype: float64

# %%
df['Petal.Length'].mode()
# Out:
# 0    1.5
# Name: Petal.Length, dtype: float64

# %% [markdown]
# ### 9 Extracting minimum and maximum value from sepal width

# %%
df['Sepal.Width'].agg(['min','max'])
# Out:
# min    2.0
# max    4.4
# Name: Sepal.Width, dtype: float64

# %% [markdown]
# ### 10 Fetch the records with petal length > 4cm

# %%
df[df['Petal.Length']>4]
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 50    51           7.0          3.2           4.7          1.4
# 51    52           6.4          3.2           4.5          1.5
# 52    53           6.9          3.1           4.9          1.5
# 54    55           6.5          2.8           4.6          1.5
# 55    56           5.7          2.8           4.5          1.3
# ..   ...           ...          ...           ...          ...
# 145  146           6.7          3.0           5.2          2.3
# 146  147           6.3          2.5           5.0          1.9
# 147  148           6.5          3.0           5.2          2.0
# 148  149           6.2          3.4           5.4          2.3
# 149  150           5.9          3.0           5.1          1.8
#
#              species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 54   Iris-versicolor
# 55   Iris-versicolor
# ..               ...
# 145   Iris-virginica
# 146   Iris-virginica
# 147   Iris-virginica
# 148   Iris-virginica
# 149   Iris-virginica
#
# [84 rows x 6 columns]

# %% [markdown]
# ### 11 Split the data based on species type and find the mean sepal length

# %%
df.groupby('species')['Sepal.Length'].mean()
# Out:
# species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: Sepal.Length, dtype: float64

# %% [markdown]
# ### 12 Add a new attribute ‘total’ that stores the sum of sepal width and petal width

# %%
df['total'] = sum(df['Sepal.Width'],df['Petal.Width'])
df
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0      1           5.1          3.5           1.4          0.2
# 1      2           4.9          3.0           1.4          0.2
# 2      3           4.7          3.2           1.3          0.2
# 3      4           4.6          3.1           1.5          0.2
# 4      5           5.0          3.6           1.4          0.2
# ..   ...           ...          ...           ...          ...
# 145  146           6.7          3.0           5.2          2.3
# 146  147           6.3          2.5           5.0          1.9
# 147  148           6.5          3.0           5.2          2.0
# 148  149           6.2          3.4           5.4          2.3
# 149  150           5.9          3.0           5.1          1.8
#
#             species  total
# 0       Iris-setosa  458.3
# 1       Iris-setosa  458.3
# 2       Iris-setosa  458.3
# 3       Iris-setosa  458.3
# 4       Iris-setosa  458.3
# ..              ...    ...
# 145  Iris-virginica  460.4
# 146  Iris-virginica  460.0
# 147  Iris-virginica  460.1
# 148  Iris-virginica  460.4
# 149  Iris-virginica  459.9
#
# [150 rows x 7 columns]

# %% [markdown]
# ### 13 Set the values of the rows 10 to 19 of the column 'petal_length' to NaN

# %%
df.loc[10:20]['Petal.Length'] = np.nan
# Out:
# /tmp/ipykernel_5788/2969380526.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[10:20]['Petal.Length'] = np.nan

# %%
df.loc[5:20]
# Out:
#     Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width      species  \
# 5    6           5.4          3.9           1.7          0.4  Iris-setosa
# 6    7           4.6          3.4           1.4          0.3  Iris-setosa
# 7    8           5.0          3.4           1.5          0.2  Iris-setosa
# 8    9           4.4          2.9           1.4          0.2  Iris-setosa
# 9   10           4.9          3.1           1.5          0.1  Iris-setosa
# 10  11           5.4          3.7           1.5          0.2  Iris-setosa
# 11  12           4.8          3.4           1.6          0.2  Iris-setosa
# 12  13           4.8          3.0           1.4          0.1  Iris-setosa
# 13  14           4.3          3.0           1.1          0.1  Iris-setosa
# 14  15           5.8          4.0           1.2          0.2  Iris-setosa
# 15  16           5.7          4.4           1.5          0.4  Iris-setosa
# 16  17           5.1          3.5           1.4          0.3  Iris-setosa
# 17  18           5.4          3.9           1.3          0.4  Iris-setosa
# 18  19           5.7          3.8           1.7          0.3  Iris-setosa
# 19  20           5.1          3.8           1.5          0.3  Iris-setosa
# 20  21           5.4          3.4           1.7          0.2  Iris-setosa
#
#     total
# 5   458.5
# 6   458.4
# 7   458.3
# 8   458.3
# 9   458.2
# 10  458.3
# 11  458.3
# 12  458.2
# 13  458.2
# 14  458.3
# 15  458.5
# 16  458.4
# 17  458.5
# 18  458.4
# 19  458.4
# 20  458.3

# %% [markdown]
# ### 14 Fill the NA values with its mean

# %%
df['Petal.Length'].fillna(df['Petal.Length'].mean())
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal.Length, Length: 150, dtype: float64

# %% [markdown]
# ### 15 Plot a histogram to show the species distribution

# %%
df.plot('species',kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
